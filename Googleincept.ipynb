# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# Out:
# 2026-05-07 09:50:00.959815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778147401.210342      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778147401.278323      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778147401.901867      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778147401.901926      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778147401.901930      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778147401.901934      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
train_path = "/kaggle/input/datasets/kaustubhdikshit/neu-surface-defect-database/NEU-DET/train/images"
test_path = "/kaggle/input/datasets/kaustubhdikshit/neu-surface-defect-database/NEU-DET/validation/images"

# %%
img_size = 128
batch_size = 16

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# %%
test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(img_size,img_size),
    batch_size=batch_size,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    test_path,
    target_size=(img_size,img_size),
    batch_size=batch_size,
    shuffle=False,
    class_mode='categorical'
)
# Out:
# Found 1440 images belonging to 6 classes.
# Found 360 images belonging to 6 classes.

# %%
print(train_data.class_indices)
print(test_data.class_indices)
# Out:
# {'crazing': 0, 'inclusion': 1, 'patches': 2, 'pitted_surface': 3, 'rolled-in_scale': 4, 'scratches': 5}
# {'crazing': 0, 'inclusion': 1, 'patches': 2, 'pitted_surface': 3, 'rolled-in_scale': 4, 'scratches': 5}

# %%
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(128,128,3)
)

base_model.trainable = False

x = base_model.output

x = GlobalAveragePooling2D()(x)

x = Dense(128,activation='relu')(x)

x = Dropout(0.5)(x)

output = Dense(6,activation='softmax')(x)

model = Model(inputs=base_model.input,outputs=output)
# Out:
# 2026-05-07 09:50:38.601294: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    optimizer=Adam(0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3
)

# %%
checkpoint = ModelCheckpoint(
    "best_inception_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=30,
    callbacks=[early_stop,reduce_lr,checkpoint]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 52s 475ms/step - accuracy: 0.2626 - loss: 2.0894 - val_accuracy: 0.6333 - val_loss: 1.1321 - learning_rate: 1.0000e-04
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 335ms/step - accuracy: 0.5693 - loss: 1.1249 - val_accuracy: 0.8028 - val_loss: 0.7627 - learning_rate: 1.0000e-04
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 341ms/step - accuracy: 0.7401 - loss: 0.8090 - val_accuracy: 0.8222 - val_loss: 0.6263 - learning_rate: 1.0000e-04
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.7872 - loss: 0.6345 - val_accuracy: 0.8500 - val_loss: 0.5229 - learning_rate: 1.0000e-04
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 338ms/step - accuracy: 0.8307 - loss: 0.5008 - val_accuracy: 0.8611 - val_loss: 0.4706 - learning_rate: 1.0000e-04
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 327ms/step - accuracy: 0.8607 - loss: 0.4316 - val_accuracy: 0.8611 - val_loss: 0.4310 - learning_rate: 1.0000e-04
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 340ms/step - accuracy: 0.8563 - loss: 0.3878 - val_accuracy: 0.8861 - val_loss: 0.3905 - learning_rate: 1.0000e-04
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 383ms/step - accuracy: 0.8767 - loss: 0.3958 - val_accuracy: 0.8750 - val_loss: 0.3636 - learning_rate: 1.0000e-04
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.9072 - loss: 0.3094 - val_accuracy: 0.8778 - val_loss: 0.3482 - learning_rate: 1.0000e-04
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 379ms/step - accuracy: 0.8889 - loss: 0.3578 - val_accuracy: 0.8806 - val_loss: 0.3354 - learning_rate: 1.0000e-04
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 325ms/step - accuracy: 0.8918 - loss: 0.3161 - val_accuracy: 0.8833 - val_loss: 0.3164 - learning_rate: 1.0000e-04
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 323ms/step - accuracy: 0.9107 - loss: 0.2779 - val_accuracy: 0.8806 - val_loss: 0.3109 - learning_rate: 1.0000e-04
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.8993 - loss: 0.2874 - val_accuracy: 0.8667 - val_loss: 0.3303 - learning_rate: 1.0000e-04
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 344ms/step - accuracy: 0.9289 - loss: 0.2339 - val_accuracy: 0.8889 - val_loss: 0.3035 - learning_rate: 1.0000e-04
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 325ms/step - accuracy: 0.9184 - loss: 0.2381 - val_accuracy: 0.8861 - val_loss: 0.3253 - learning_rate: 1.0000e-04
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.9179 - loss: 0.2562 - val_accuracy: 0.8889 - val_loss: 0.2999 - learning_rate: 1.0000e-04
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 323ms/step - accuracy: 0.9350 - loss: 0.2179 - val_accuracy: 0.8861 - val_loss: 0.3117 - learning_rate: 1.0000e-04
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 325ms/step - accuracy: 0.9147 - loss: 0.2258 - val_accuracy: 0.8833 - val_loss: 0.2904 - learning_rate: 1.0000e-04
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 35s 391ms/step - accuracy: 0.9342 - loss: 0.1935 - val_accuracy: 0.8972 - val_loss: 0.2853 - learning_rate: 1.0000e-04
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 336ms/step - accuracy: 0.9340 - loss: 0.2089 - val_accuracy: 0.9028 - val_loss: 0.2773 - learning_rate: 1.0000e-04
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.9362 - loss: 0.1859 - val_accuracy: 0.9167 - val_loss: 0.2676 - learning_rate: 1.0000e-04
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.9397 - loss: 0.1613 - val_accuracy: 0.9111 - val_loss: 0.2562 - learning_rate: 1.0000e-04
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.9415 - loss: 0.1752 - val_accuracy: 0.9028 - val_loss: 0.2637 - learning_rate: 1.0000e-04
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 379ms/step - accuracy: 0.9380 - loss: 0.2083 - val_accuracy: 0.9083 - val_loss: 0.2559 - learning_rate: 1.0000e-04
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 341ms/step - accuracy: 0.9291 - loss: 0.2320 - val_accuracy: 0.9361 - val_loss: 0.2157 - learning_rate: 1.0000e-04
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 323ms/step - accuracy: 0.9498 - loss: 0.1565 - val_accuracy: 0.9250 - val_loss: 0.2389 - learning_rate: 1.0000e-04
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 335ms/step - accuracy: 0.9381 - loss: 0.1873 - val_accuracy: 0.9389 - val_loss: 0.2088 - learning_rate: 1.0000e-04
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 377ms/step - accuracy: 0.9455 - loss: 0.1588 - val_accuracy: 0.9222 - val_loss: 0.2524 - learning_rate: 1.0000e-04
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 345ms/step - accuracy: 0.9504 - loss: 0.1616 - val_accuracy: 0.9222 - val_loss: 0.2228 - learning_rate: 1.0000e-04
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 323ms/step - accuracy: 0.9477 - loss: 0.1581 - val_accuracy: 0.9306 - val_loss: 0.2159 - learning_rate: 1.0000e-04

# %%
model = tf.keras.models.load_model(
    "best_inception_model.keras"
)

# %%
loss,accuracy = model.evaluate(test_data)

print("Test Accuracy :",accuracy)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 233ms/step - accuracy: 0.9351 - loss: 0.2060
# Test Accuracy : 0.9388889074325562

# %%
pred = model.predict(test_data)

pred_classes = np.argmax(pred,axis=1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step

# %%
print(classification_report(
    test_data.classes,
    pred_classes
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        60
#            1       0.98      0.83      0.90        60
#            2       0.97      1.00      0.98        60
#            3       0.86      0.95      0.90        60
#            4       0.90      0.95      0.93        60
#            5       0.98      0.93      0.96        60
#
#     accuracy                           0.94       360
#    macro avg       0.94      0.94      0.94       360
# weighted avg       0.94      0.94      0.94       360

# %%
cm = confusion_matrix(
    test_data.classes,
    pred_classes
)
plt.figure(figsize=(8,8))
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.colorbar()
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend(['Train','Validation'])

plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(['Train','Validation'])

plt.show()
